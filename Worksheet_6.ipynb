# %% [markdown]
# <a href="https://colab.research.google.com/github/brishashrestha/Portfolio/blob/main/Worksheet_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Understanding and Visualizations.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Import Required Libraries

# %%
# Import required libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from PIL import Image, UnidentifiedImageError
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import seaborn as sns

# Ensure reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Check TensorFlow version
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.18.0

# %% [markdown]
# ## 2. Dataset Preparation

# %% [markdown]
# ### 2.1 Verify Dataset Structure

# %%
# Define paths and parameters
train_dir = "/content/drive/MyDrive/AI/FruitinAmazon/train"
test_dir = "/content/drive/MyDrive/AI/FruitinAmazon/test"

img_size = (224, 224)
batch_size = 32

# Get class names
class_names = sorted(os.listdir(train_dir))
if not class_names:
    print("No class directories found in the train folder!")
else:
    print(f"Found {len(class_names)} classes: {class_names}")
# Out:
# Found 6 classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %% [markdown]
# ### 2.2 Check for Corrupted Images

# %%
from PIL import Image, UnidentifiedImageError

corrupted_images = []  # List to store corrupted image paths

# Loop through each class folder and check for corrupted images
for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):  # Ensure it’s a valid directory
        images = os.listdir(class_path)
        for img_name in images:
            img_path = os.path.join(class_path, img_name)
            try:
                with Image.open(img_path) as img:
                    img.verify()  # Verify image integrity
            except (IOError, UnidentifiedImageError):
                corrupted_images.append(img_path)

# Print results
if corrupted_images:
    print("\nCorrupted Images Found:")
    for img in corrupted_images:
        print(img)
else:
    print("\nNo corrupted images found.")
# Out:
# No corrupted images found.

# %% [markdown]
# ### 2.3 Count Class Balance

# %%
# Dictionary to store class counts
class_counts = {}

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        images = [img for img in os.listdir(class_path) if img.lower().endswith(('.png', '.jpg', '.jpeg'))]
        class_counts[class_name] = len(images)  # Count images in each class

# Print class balance
print("\nClass Distribution:")
print("=" * 45)
print(f"{'Class Name':<25}{'Valid Image Count':>15}")
print("=" * 45)
for class_name, count in class_counts.items():
    print(f"{class_name:<25}{count:>15}")
print("=" * 45)
# Out:
# Class Distribution:
# =============================================
# Class Name               Valid Image Count
# =============================================
# acai                                  15
# cupuacu                               15
# graviola                              15
# guarana                               15
# pupunha                               15
# tucuma                                15
# =============================================

# %% [markdown]
# ### 2.4 Select Random Images for Visualization

# %%
import random

selected_images = []  # Store image paths
selected_labels = []  # Store corresponding class names

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        images = [img for img in os.listdir(class_path) if img.lower().endswith(('.png', '.jpg', '.jpeg'))]
        if images:  # Ensure the class folder is not empty
            selected_img = os.path.join(class_path, random.choice(images))
            selected_images.append(selected_img)
            selected_labels.append(class_name)

# Display randomly selected images in a grid format
num_classes = len(selected_images)
cols = (num_classes + 1) // 2  # Determine columns
rows = 2  # Fixed rows for layout

fig, axes = plt.subplots(rows, cols, figsize=(12, 6))
for i, ax in enumerate(axes.flat):
    if i < num_classes:
        img = plt.imread(selected_images[i])
        ax.imshow(img)
        ax.set_title(selected_labels[i])
        ax.axis("off")
    else:
        ax.axis("off")  # Hide empty subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Data Generation and Preprocessing

# %% [markdown]
# ### 3.1 Generate Train and Validation Datasets

# %%
# Load datasets
train_ds = image_dataset_from_directory(
    train_dir,
    seed=1337,
    image_size=img_size,
    batch_size=batch_size,
)

test_ds = image_dataset_from_directory(
    test_dir,
    seed=1337,
    image_size=img_size,
    batch_size=batch_size,
)

# Prefetch datasets for better performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 90 files belonging to 6 classes.
# Found 30 files belonging to 6 classes.

# %%
# Checking the shape of a batch
for images, labels in train_ds.take(1): # Take one batch
  print("Images shape:", images.shape)
  print("Labels shape:", labels.shape)
# Out:
# Images shape: (32, 224, 224, 3)
# Labels shape: (32,)

# %% [markdown]
# ### 3.2 Visualize Training Dataset

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
plt.show()

# %% [markdown]
# ### 3.3 Data Augmentation

# %%
# Define the data augmentation layers
data_augmentation = Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(0.2, 0.2),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.2),
])

# %% [markdown]
# ### Visualize augmented images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):  # Take 1 batch from original dataset
    augmented_images = data_augmentation(images)  # Apply augmentations
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[i].numpy().astype("uint8"))
        plt.axis("off")
    break
plt.show()

# %% [markdown]
# ## 4. Model Building

# %% [markdown]
# ### 4.1 Define the CNN Model

# %%
from tensorflow.keras.layers import (Lambda, Rescaling, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Flatten, Dense, Input, GlobalAveragePooling2D)

# Define the model using the Sequential API with a list of layers
model = Sequential([
    # Define the input shape using InputLayer
    Input(shape=(224, 224, 3)),

    # Data Augmentation using Lambda
    Lambda(data_augmentation, input_shape=(224, 224, 3)),

    # Rescaling layer
    Rescaling(1./255),

    # First Convolutional Block
    Conv2D(32, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Second Convolutional Block
    Conv2D(64, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Third Convolutional Block
    Conv2D(128, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Fourth Convolutional Block
    Conv2D(256, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Flatten before fully connected layers
    Flatten(),

    # Fully Connected Layer 1
    Dense(512, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Fully Connected Layer 2
    Dense(256, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Fully Connected Layer 3
    Dense(128, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Fully Connected Layer 4
    Dense(64, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Output layer (10 classes)
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/lambda_layer.py:65: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lambda (Lambda)                 │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    25,690,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,257,930 (100.17 MB)
#  Trainable params: 26,255,050 (100.16 MB)
#  Non-trainable params: 2,880 (11.25 KB)

# %% [markdown]
# ## 5. Training the Model

# %% [markdown]
# ### 5.1 Add Callbacks

# %%
# Define Early Stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',          # Monitor validation loss
    patience=10,                 # Wait for 10 epochs before stopping
    restore_best_weights=True   # Restore weights from the best epoch
)

# Define Learning Rate Reduction on Plateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',          # Monitor validation loss
    factor=0.5,                  # Reduce learning rate by a factor of 0.5
    patience=3,                  # Wait for 3 epochs before reducing LR
    min_lr=1e-6                  # Minimum learning rate
)

# %% [markdown]
# ## 5.2 Train the Model

# %%
# Train the model
history = model.fit(
    train_ds,
    validation_data=test_ds,     # Use test_ds for validation
    epochs=100,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 6s/step - accuracy: 0.1018 - loss: 2.8940 - val_accuracy: 0.1000 - val_loss: 2.3467 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - accuracy: 0.1002 - loss: 2.9677 - val_accuracy: 0.1667 - val_loss: 2.3045 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.0724 - loss: 2.9181 - val_accuracy: 0.1667 - val_loss: 2.3081 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.0891 - loss: 2.9506 - val_accuracy: 0.1667 - val_loss: 2.3186 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.0607 - loss: 2.7909 - val_accuracy: 0.1667 - val_loss: 2.3158 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.0829 - loss: 2.6724 - val_accuracy: 0.1667 - val_loss: 2.3090 - learning_rate: 5.0000e-04
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.1865 - loss: 2.5844 - val_accuracy: 0.1667 - val_loss: 2.3058 - learning_rate: 5.0000e-04
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 0.1448 - loss: 2.6559 - val_accuracy: 0.1667 - val_loss: 2.2996 - learning_rate: 5.0000e-04
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 0.2707 - loss: 2.4751 - val_accuracy: 0.1667 - val_loss: 2.3043 - learning_rate: 5.0000e-04
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step - accuracy: 0.1370 - loss: 2.7028 - val_accuracy: 0.1667 - val_loss: 2.3039 - learning_rate: 5.0000e-04
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step - accuracy: 0.1002 - loss: 2.6417 - val_accuracy: 0.1667 - val_loss: 2.2973 - learning_rate: 5.0000e-04
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - accuracy: 0.1448 - loss: 2.6380 - val_accuracy: 0.1667 - val_loss: 2.2919 - learning_rate: 5.0000e-04
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - accuracy: 0.1804 - loss: 2.4664 - val_accuracy: 0.1667 - val_loss: 2.2880 - learning_rate: 5.0000e-04
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - accuracy: 0.1915 - loss: 2.6479 - val_accuracy: 0.1667 - val_loss: 2.2875 - learning_rate: 5.0000e-04
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 406ms/step - accuracy: 0.1804 - loss: 2.3470 - val_accuracy: 0.1667 - val_loss: 2.2822 - learning_rate: 5.0000e-04
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - accuracy: 0.1370 - loss: 2.4109 - val_accuracy: 0.1667 - val_loss: 2.2659 - learning_rate: 5.0000e-04
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 305ms/step - accuracy: 0.1804 - loss: 2.4312 - val_accuracy: 0.1667 - val_loss: 2.2616 - learning_rate: 5.0000e-04
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.2968 - loss: 2.0866 - val_accuracy: 0.1667 - val_loss: 2.2583 - learning_rate: 5.0000e-04
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.1269 - loss: 2.3243 - val_accuracy: 0.1667 - val_loss: 2.2606 - learning_rate: 5.0000e-04
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 0.3336 - loss: 1.9712 - val_accuracy: 0.1667 - val_loss: 2.2752 - learning_rate: 5.0000e-04
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - accuracy: 0.2522 - loss: 2.1690 - val_accuracy: 0.1667 - val_loss: 2.2926 - learning_rate: 5.0000e-04
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.2867 - loss: 2.0503 - val_accuracy: 0.1667 - val_loss: 2.3027 - learning_rate: 2.5000e-04
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.2205 - loss: 2.1258 - val_accuracy: 0.1667 - val_loss: 2.3235 - learning_rate: 2.5000e-04
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.2694 - loss: 2.1069 - val_accuracy: 0.1667 - val_loss: 2.3516 - learning_rate: 2.5000e-04
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.2918 - loss: 1.8963 - val_accuracy: 0.1667 - val_loss: 2.3684 - learning_rate: 1.2500e-04
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.2589 - loss: 2.0865 - val_accuracy: 0.1667 - val_loss: 2.3808 - learning_rate: 1.2500e-04
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 0.3581 - loss: 1.8188 - val_accuracy: 0.1667 - val_loss: 2.3969 - learning_rate: 1.2500e-04
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.2684 - loss: 2.0501 - val_accuracy: 0.1667 - val_loss: 2.4073 - learning_rate: 6.2500e-05

# %% [markdown]
# ## 6. Evaluate the Model

# %% [markdown]
# ## 6.1 Plot Training History

# %%
plt.figure(figsize=(12, 4))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Using Keras ImageDataGenerator (Old API)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    zoom_range=0.3,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load Data
train_data = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_data = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical', shuffle=False)

# Load Pretrained Model (MobileNetV2)
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze initial layers

# Define Model
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(train_data.class_indices), activation='softmax')
])

# Compile Model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

# Train Model
history = model.fit(train_data, validation_data=test_data, epochs=70, callbacks=[early_stopping, lr_scheduler])

# Save the trained model
model.save("fruit_classification_model_v2.h5")

# Load the saved model
loaded_model = tf.keras.models.load_model("fruit_classification_model_v2.h5")

# Re-evaluate the model
y_true = test_data.classes
y_pred = np.argmax(loaded_model.predict(test_data), axis=1)
class_labels = list(test_data.class_indices.keys())

print("Re-evaluated Model Performance:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=class_labels, yticklabels=class_labels, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Plot Training Performance
plt.figure(figsize=(12,4))

# Accuracy Plot
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Curve")

# Loss Plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Curve")

plt.show()
# Out:
# Found 90 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 23s 6s/step - accuracy: 0.1589 - loss: 3.0510 - val_accuracy: 0.4333 - val_loss: 2.0265 - learning_rate: 1.0000e-04
# Epoch 2/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 812ms/step - accuracy: 0.2458 - loss: 2.8575 - val_accuracy: 0.4333 - val_loss: 1.9292 - learning_rate: 1.0000e-04
# Epoch 3/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 570ms/step - accuracy: 0.2309 - loss: 2.8029 - val_accuracy: 0.5000 - val_loss: 1.8348 - learning_rate: 1.0000e-04
# Epoch 4/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 759ms/step - accuracy: 0.3672 - loss: 2.2461 - val_accuracy: 0.5333 - val_loss: 1.7469 - learning_rate: 1.0000e-04
# Epoch 5/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 682ms/step - accuracy: 0.4095 - loss: 2.0669 - val_accuracy: 0.6000 - val_loss: 1.6677 - learning_rate: 1.0000e-04
# Epoch 6/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 555ms/step - accuracy: 0.5321 - loss: 1.9537 - val_accuracy: 0.6000 - val_loss: 1.5934 - learning_rate: 1.0000e-04
# Epoch 7/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 560ms/step - accuracy: 0.4727 - loss: 1.9437 - val_accuracy: 0.6667 - val_loss: 1.5274 - learning_rate: 1.0000e-04
# Epoch 8/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 561ms/step - accuracy: 0.4548 - loss: 1.8466 - val_accuracy: 0.6667 - val_loss: 1.4656 - learning_rate: 1.0000e-04
# Epoch 9/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 0.4850 - loss: 1.8428 - val_accuracy: 0.6667 - val_loss: 1.4091 - learning_rate: 1.0000e-04
# Epoch 10/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 557ms/step - accuracy: 0.6338 - loss: 1.5297 - val_accuracy: 0.7000 - val_loss: 1.3568 - learning_rate: 1.0000e-04
# Epoch 11/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 760ms/step - accuracy: 0.6299 - loss: 1.3800 - val_accuracy: 0.7000 - val_loss: 1.3110 - learning_rate: 1.0000e-04
# Epoch 12/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 852ms/step - accuracy: 0.6986 - loss: 1.3665 - val_accuracy: 0.7000 - val_loss: 1.2685 - learning_rate: 1.0000e-04
# Epoch 13/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 579ms/step - accuracy: 0.6898 - loss: 1.2501 - val_accuracy: 0.7333 - val_loss: 1.2293 - learning_rate: 1.0000e-04
# Epoch 14/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 622ms/step - accuracy: 0.7446 - loss: 1.2204 - val_accuracy: 0.7333 - val_loss: 1.1936 - learning_rate: 1.0000e-04
# Epoch 15/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 578ms/step - accuracy: 0.7979 - loss: 1.1173 - val_accuracy: 0.7333 - val_loss: 1.1590 - learning_rate: 1.0000e-04
# Epoch 16/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 576ms/step - accuracy: 0.7912 - loss: 1.1663 - val_accuracy: 0.7333 - val_loss: 1.1284 - learning_rate: 1.0000e-04
# Epoch 17/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 627ms/step - accuracy: 0.7597 - loss: 1.1526 - val_accuracy: 0.7333 - val_loss: 1.1010 - learning_rate: 1.0000e-04
# Epoch 18/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 725ms/step - accuracy: 0.8224 - loss: 0.9581 - val_accuracy: 0.7333 - val_loss: 1.0777 - learning_rate: 1.0000e-04
# Epoch 19/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 773ms/step - accuracy: 0.8574 - loss: 0.9195 - val_accuracy: 0.7333 - val_loss: 1.0573 - learning_rate: 1.0000e-04
# Epoch 20/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 597ms/step - accuracy: 0.8289 - loss: 0.9589 - val_accuracy: 0.7333 - val_loss: 1.0393 - learning_rate: 1.0000e-04
# Epoch 21/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 599ms/step - accuracy: 0.8522 - loss: 0.8257 - val_accuracy: 0.7333 - val_loss: 1.0210 - learning_rate: 1.0000e-04
# Epoch 22/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 569ms/step - accuracy: 0.8653 - loss: 0.7930 - val_accuracy: 0.7333 - val_loss: 1.0016 - learning_rate: 1.0000e-04
# Epoch 23/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 563ms/step - accuracy: 0.8636 - loss: 0.8898 - val_accuracy: 0.7333 - val_loss: 0.9827 - learning_rate: 1.0000e-04
# Epoch 24/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 573ms/step - accuracy: 0.7880 - loss: 0.8690 - val_accuracy: 0.7333 - val_loss: 0.9645 - learning_rate: 1.0000e-04
# Epoch 25/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 872ms/step - accuracy: 0.8851 - loss: 0.8708 - val_accuracy: 0.7333 - val_loss: 0.9493 - learning_rate: 1.0000e-04
# Epoch 26/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 731ms/step - accuracy: 0.8753 - loss: 0.7547 - val_accuracy: 0.7333 - val_loss: 0.9348 - learning_rate: 1.0000e-04
# Epoch 27/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 622ms/step - accuracy: 0.8536 - loss: 0.8091 - val_accuracy: 0.7667 - val_loss: 0.9198 - learning_rate: 1.0000e-04
# Epoch 28/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 584ms/step - accuracy: 0.7439 - loss: 1.0412 - val_accuracy: 0.7667 - val_loss: 0.9059 - learning_rate: 1.0000e-04
# Epoch 29/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 563ms/step - accuracy: 0.8886 - loss: 0.7863 - val_accuracy: 0.7667 - val_loss: 0.8940 - learning_rate: 1.0000e-04
# Epoch 30/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 574ms/step - accuracy: 0.8418 - loss: 0.8183 - val_accuracy: 0.7667 - val_loss: 0.8817 - learning_rate: 1.0000e-04
# Epoch 31/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 576ms/step - accuracy: 0.9204 - loss: 0.7236 - val_accuracy: 0.7667 - val_loss: 0.8710 - learning_rate: 1.0000e-04
# Epoch 32/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 847ms/step - accuracy: 0.8510 - loss: 0.9010 - val_accuracy: 0.8000 - val_loss: 0.8581 - learning_rate: 1.0000e-04
# Epoch 33/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 861ms/step - accuracy: 0.8662 - loss: 0.7825 - val_accuracy: 0.8000 - val_loss: 0.8450 - learning_rate: 1.0000e-04
# Epoch 34/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 612ms/step - accuracy: 0.8897 - loss: 0.7927 - val_accuracy: 0.8000 - val_loss: 0.8334 - learning_rate: 1.0000e-04
# Epoch 35/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 623ms/step - accuracy: 0.9246 - loss: 0.6849 - val_accuracy: 0.8333 - val_loss: 0.8218 - learning_rate: 1.0000e-04
# Epoch 36/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 568ms/step - accuracy: 0.8819 - loss: 0.7924 - val_accuracy: 0.8333 - val_loss: 0.8094 - learning_rate: 1.0000e-04
# Epoch 37/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.9359 - loss: 0.7121 - val_accuracy: 0.8333 - val_loss: 0.7984 - learning_rate: 1.0000e-04
# Epoch 38/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 611ms/step - accuracy: 0.9343 - loss: 0.6411 - val_accuracy: 0.8333 - val_loss: 0.7878 - learning_rate: 1.0000e-04
# Epoch 39/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 731ms/step - accuracy: 0.9401 - loss: 0.6174 - val_accuracy: 0.8667 - val_loss: 0.7782 - learning_rate: 1.0000e-04
# Epoch 40/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 652ms/step - accuracy: 0.9295 - loss: 0.7032 - val_accuracy: 0.8667 - val_loss: 0.7683 - learning_rate: 1.0000e-04
# Epoch 41/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.9354 - loss: 0.6392 - val_accuracy: 0.8667 - val_loss: 0.7596 - learning_rate: 1.0000e-04
# Epoch 42/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 563ms/step - accuracy: 0.9354 - loss: 0.6236 - val_accuracy: 0.8667 - val_loss: 0.7522 - learning_rate: 1.0000e-04
# Epoch 43/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 665ms/step - accuracy: 0.9062 - loss: 0.6839 - val_accuracy: 0.8667 - val_loss: 0.7473 - learning_rate: 1.0000e-04
# Epoch 44/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 623ms/step - accuracy: 0.9299 - loss: 0.6346 - val_accuracy: 0.8667 - val_loss: 0.7439 - learning_rate: 1.0000e-04
# Epoch 45/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 603ms/step - accuracy: 0.9657 - loss: 0.5991 - val_accuracy: 0.8667 - val_loss: 0.7393 - learning_rate: 1.0000e-04
# Epoch 46/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 821ms/step - accuracy: 0.9465 - loss: 0.6272 - val_accuracy: 0.9000 - val_loss: 0.7321 - learning_rate: 1.0000e-04
# Epoch 47/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 610ms/step - accuracy: 0.9159 - loss: 0.6648 - val_accuracy: 0.9000 - val_loss: 0.7259 - learning_rate: 1.0000e-04
# Epoch 48/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 584ms/step - accuracy: 0.9303 - loss: 0.6283 - val_accuracy: 0.9000 - val_loss: 0.7206 - learning_rate: 1.0000e-04
# Epoch 49/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 621ms/step - accuracy: 0.9456 - loss: 0.6236 - val_accuracy: 0.9000 - val_loss: 0.7139 - learning_rate: 1.0000e-04
# Epoch 50/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9272 - loss: 0.6616 - val_accuracy: 0.9000 - val_loss: 0.7088 - learning_rate: 1.0000e-04
# Epoch 51/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 560ms/step - accuracy: 0.9661 - loss: 0.5664 - val_accuracy: 0.9000 - val_loss: 0.7031 - learning_rate: 1.0000e-04
# Epoch 52/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 571ms/step - accuracy: 0.9488 - loss: 0.5641 - val_accuracy: 0.9000 - val_loss: 0.6984 - learning_rate: 1.0000e-04
# Epoch 53/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 814ms/step - accuracy: 0.9510 - loss: 0.5847 - val_accuracy: 0.9000 - val_loss: 0.6944 - learning_rate: 1.0000e-04
# Epoch 54/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 744ms/step - accuracy: 0.9075 - loss: 0.7171 - val_accuracy: 0.9000 - val_loss: 0.6897 - learning_rate: 1.0000e-04
# Epoch 55/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.9471 - loss: 0.7077 - val_accuracy: 0.9000 - val_loss: 0.6847 - learning_rate: 1.0000e-04
# Epoch 56/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 569ms/step - accuracy: 0.9282 - loss: 0.5765 - val_accuracy: 0.9000 - val_loss: 0.6802 - learning_rate: 1.0000e-04
# Epoch 57/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 645ms/step - accuracy: 0.9504 - loss: 0.6206 - val_accuracy: 0.9000 - val_loss: 0.6769 - learning_rate: 1.0000e-04
# Epoch 58/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 618ms/step - accuracy: 0.9246 - loss: 0.6499 - val_accuracy: 0.9000 - val_loss: 0.6738 - learning_rate: 1.0000e-04
# Epoch 59/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.9411 - loss: 0.5682 - val_accuracy: 0.9000 - val_loss: 0.6705 - learning_rate: 1.0000e-04
# Epoch 60/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 564ms/step - accuracy: 0.9472 - loss: 0.5869 - val_accuracy: 0.9000 - val_loss: 0.6674 - learning_rate: 1.0000e-04
# Epoch 61/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 633ms/step - accuracy: 0.9805 - loss: 0.5289 - val_accuracy: 0.9000 - val_loss: 0.6650 - learning_rate: 1.0000e-04
# Epoch 62/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 571ms/step - accuracy: 0.9410 - loss: 0.5581 - val_accuracy: 0.9000 - val_loss: 0.6622 - learning_rate: 1.0000e-04
# Epoch 63/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 627ms/step - accuracy: 0.9901 - loss: 0.5281 - val_accuracy: 0.9000 - val_loss: 0.6589 - learning_rate: 1.0000e-04
# Epoch 64/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 745ms/step - accuracy: 0.9160 - loss: 0.6721 - val_accuracy: 0.9000 - val_loss: 0.6553 - learning_rate: 1.0000e-04
# Epoch 65/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 867ms/step - accuracy: 0.9543 - loss: 0.5786 - val_accuracy: 0.9000 - val_loss: 0.6517 - learning_rate: 1.0000e-04
# Epoch 66/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 655ms/step - accuracy: 0.9087 - loss: 0.5849 - val_accuracy: 0.9000 - val_loss: 0.6502 - learning_rate: 1.0000e-04
# Epoch 67/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 593ms/step - accuracy: 0.9772 - loss: 0.5312 - val_accuracy: 0.9000 - val_loss: 0.6489 - learning_rate: 1.0000e-04
# Epoch 68/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 584ms/step - accuracy: 0.9944 - loss: 0.5338 - val_accuracy: 0.9000 - val_loss: 0.6492 - learning_rate: 1.0000e-04
# Epoch 69/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 527ms/step - accuracy: 0.9772 - loss: 0.5344 - val_accuracy: 0.9000 - val_loss: 0.6495 - learning_rate: 1.0000e-04
# Epoch 70/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 506ms/step - accuracy: 0.9944 - loss: 0.4996 - val_accuracy: 0.9000 - val_loss: 0.6489 - learning_rate: 1.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Re-evaluated Model Performance:
#               precision    recall  f1-score   support
#
#         acai       0.83      1.00      0.91         5
#      cupuacu       1.00      1.00      1.00         5
#     graviola       1.00      1.00      1.00         5
#      guarana       1.00      1.00      1.00         5
#      pupunha       0.80      0.80      0.80         5
#       tucuma       0.75      0.60      0.67         5
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# # Task 2: Transfer Learning with MobileNetV2

# %%
# Set image size compatible with MobileNetV2
IMAGE_SIZE = (128, 128)
BATCH_SIZE = 32

# Prepare ImageDataGenerators
train_ds = ImageDataGenerator(rescale=1./255)
val_ds = ImageDataGenerator(rescale=1./255)

# %%
train_gen = train_ds.flow_from_directory(
    '/content/drive/MyDrive/AI/FruitinAmazon/train',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_gen = val_ds.flow_from_directory(
    '/content/drive/MyDrive/AI/FruitinAmazon/test',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 90 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.

# %% [markdown]
# ## 1. Load the base model

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# Freeze all layers in the base model
for layer in base_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ## 2. Add custom layers on top

# %%
from tensorflow.keras.models import Model

# Add custom layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(train_gen.num_classes, activation='softmax')(x)

# Final model
model_tl = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model_tl.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 3. Train the model

# %%
history_tl = model_tl.fit(
    train_gen,
    validation_data=val_gen,
    epochs=5
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 4s/step - accuracy: 0.1475 - loss: 2.5349 - val_accuracy: 0.3000 - val_loss: 1.8693
# Epoch 2/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 0.5144 - loss: 1.4274 - val_accuracy: 0.4667 - val_loss: 1.3147
# Epoch 3/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - accuracy: 0.6752 - loss: 0.9415 - val_accuracy: 0.6667 - val_loss: 1.0269
# Epoch 4/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - accuracy: 0.8437 - loss: 0.4922 - val_accuracy: 0.7000 - val_loss: 0.8584
# Epoch 5/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9126 - loss: 0.3194 - val_accuracy: 0.7333 - val_loss: 0.7658

# %% [markdown]
# ## 4. Evaluate model performance

# %%
val_loss_tl, val_acc_tl = model_tl.evaluate(val_gen)
print(f"Validation Accuracy: {val_acc_tl:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7333 - loss: 0.7658
# Validation Accuracy: 0.7333

# %% [markdown]
# ## 5. Generate predictions and classification report

# %%
y_true = val_gen.classes
y_pred_probs = model_tl.predict(val_gen)
y_pred = np.argmax(y_pred_probs, axis=1)

# Classification Report
class_labels = list(val_gen.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=class_labels)
print("\nClassification Report:\n")
print(report)

# Inference output (show first 10 predictions)
print("\nSample Inference Results:")
for i in range(10):
    print(f"True: {class_labels[y_true[i]]}, Predicted: {class_labels[y_pred[i]]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         acai       0.75      0.60      0.67         5
#      cupuacu       0.80      0.80      0.80         5
#     graviola       1.00      1.00      1.00         5
#      guarana       0.56      1.00      0.71         5
#      pupunha       1.00      0.40      0.57         5
#       tucuma       0.60      0.60      0.60         5
#
#     accuracy                           0.73        30
#    macro avg       0.78      0.73      0.73        30
# weighted avg       0.78      0.73      0.73        30
#
#
# Sample Inference Results:
# True: acai, Predicted: acai
# True: acai, Predicted: acai
# True: acai, Predicted: acai
# True: acai, Predicted: cupuacu
# True: acai, Predicted: guarana
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: tucuma
